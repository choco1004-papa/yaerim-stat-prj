# %%
import pandas as pd
import string
# testeee
with open("refined.txt", "a+", encoding='latin_1') as write_file :
    with open("JHW_P1.txt", 'r', encoding='latin_1') as file_read:
      while True :
          line = file_read.readline()
          if not line : break
          if line.find("<960>=") >= 0 : 
              print(line.find("<960>="))
              write_file.write(line[24:])
with open("refined.txt", "r", encoding='latin_1') as re_read :
    print("정리된 파일의 줄 수 => ", len(re_read.readlines()))
# Out:
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# ...
